# %% [markdown]
# ## Q1. What is the Probability density function?

# %% [markdown]
# The Probability Density Function (PDF) is a fundamental concept in probability theory and statistics. It describes the probability distribution of a continuous random variable. In simpler terms, the PDF is a mathematical function that characterizes the likelihood of a continuous random variable taking on a particular value within a given range.
#
# For a continuous random variable X, the PDF is denoted as f(x) and is defined as follows:
#
# The PDF is non-negative: f(x) ≥ 0 for all x.
#
# The area under the PDF curve over the entire range of X is equal to 1. In mathematical terms:
#
# ∫[a, b] f(x) dx = 1,
#
# where the integral ∫[a, b] represents the area under the curve of f(x) from x = a to x = b.
#
# The PDF provides valuable information about the probability distribution of a continuous random variable. It shows how the probability is distributed over the entire range of possible values of X. However, unlike the probability mass function (PMF) used for discrete random variables, the PDF does not directly give the probability of obtaining a specific value, but rather the probability density at that point.
#
# To find the probability of X falling within a particular interval [a, b], you can integrate the PDF over that interval:
#
# P(a ≤ X ≤ b) = ∫[a, b] f(x) dx.
#
# ![PDF.jpg](attachment:55ea1aab-671a-4c8f-9a7a-4df96e11ae53.jpg)
#
# - In Statistics, it is used to calculate the probabilities associated with the random variables.
# - The probability density function is used in modelling the annual data of atmospheric NOx temporal concentration
# - It is used to model the diesel engine combustion.

# %% [markdown]
# ## Q2. What are the types of Probability distribution?

# %% [markdown]
# The probability distribution is divided into two parts:
#
# 1. Discrete Probability Distributions
# - Binomial Distribution
# - Bernoulli's Distribution
# - Poisson Distribution
# 2. Continuous Probability Distributions
# - Normal Distribution
# - Continuous Uniform Distribution
# - Log-Normal Distribution
# - Exponential Distribution
#
#
# ## Discrete Probability Distribution:
#
# A discrete distribution describes the probability of occurrence of each value of a discrete random variable. The number of spoiled apples out of 6 in your refrigerator can be an example of a discrete probability distribution.
# Each possible value of the discrete random variable can be associated with a non-zero probability in a discrete probability distribution.
#
#
#
# #### 1. Binomial Distribution:
# - The binomial distribution is a discrete distribution with a finite number of possibilities. When observing a series of what are known as Bernoulli trials, the binomial distribution emerges. A Bernoulli trial is a scientific experiment with only two outcomes: success or failure.
# - Consider a random experiment in which you toss a biased coin six times with a 0.4 chance of getting head. If 'getting a head' is considered a ‘success’, the binomial distribution will show the probability of r successes for each value of r.
# - The binomial random variable represents the number of successes (r) in n consecutive independent Bernoulli trials.
# - It is often used in experiments where there are only two possible outcomes, such as coin flips or medical treatments.
#
# #### 2. Bernoulli's Distribution:
# - The Bernoulli distribution is a variant of the Binomial distribution in which only one experiment is conducted, resulting in a single observation. As a result, the Bernoulli distribution describes events that have exactly two outcomes.The experiment's outcome can be a value of 0 or 1.
# - The Bernoulli random variable's expected value is p, which is also known as the Bernoulli distribution's parameter.
# - Bernoulli random variables can have values of 0 or 1.
#
# #### 3. Poisson Distribution:
# - Siméon Denis Poisson, a French mathematician, was the inspiration for the name.
# - This distribution describes the number of occurrences of a rare event within a fixed time or space.
# - A Poisson distribution is a probability distribution used in statistics to show how many times an event is likely to happen over a given period of time. To put it another way, it's a count distribution. Poisson distributions are frequently used to comprehend independent events at a constant rate over a given time interval.
# - It is often used in modeling the number of customers arriving at a store or the number of defects in a manufacturing process.
# - It has two parameters: <br> 1. Lam: Known number of occurrences <br>2. Size: The shape of the returned array
#
#
# ## Continous Probability Distribution:
#
# A continuous distribution describes the probabilities of a continuous random variable's possible values. A continuous random variable has an infinite and uncountable set of possible values (known as the range). The mapping of time can be considered as an example of the continuous probability distribution. It can be from 1 second to 1 billion seconds, and so on.
#
# The area under the curve of a continuous random variable's PDF is used to calculate its probability. As a result, only value ranges can have a non-zero probability. A continuous random variable's probability of equaling some value is always zero.
#
#
# #### 1. Normal Distribution:
# - Normal Distribution is one of the most basic continuous distribution types. Gaussian distribution is another name for it. Around its mean value, this probability distribution is symmetrical. It also demonstrates that data close to the mean occurs more frequently than data far from it. Here, the mean is 0, and the variance is a finite value.
# - For example, you generated 100 random variables ranging from 1 to 50. After that, you created a function to define the normal distribution formula to calculate the probability density function. Then, you have plotted the data points and probability density function against X-axis and Y-axis, respectively.
#
# #### 2. Continuous Uniform Distribution:
# In continuous uniform distribution, all outcomes are equally possible. Each variable has the same chance of being hit as a result. Random variables are spaced evenly in this symmetric probabilistic distribution, with a 1/ (b-a) probability.
#
# #### 3. Log-Normal Distribution:
# The random variables whose logarithm values follow a normal distribution are plotted using this distribution. Take a look at the random variables X and Y. The variable represented in this distribution is Y = ln(X), where ln denotes the natural logarithm of X values.
#
# #### 4. Exponential Distribution:
# In a Poisson process, an exponential distribution is a continuous probability distribution that describes the time between events (success, failure, arrival, etc.).

# %%
#Binomial Distribution
from scipy.stats import binom
import matplotlib.pyplot as plt
# setting the values of n & p
n = 5 
p = 0.4
#defining the list of r values
r_values = list(range(n+1))
#list of pmf values
dist = [binom.pmf(r,n,p) for r in r_values]
plt.figure(figsize=(6,4))
plt.title("Binomial Distribution")
plt.xlabel("Values of Random Variable r_values")
plt.ylabel("Probability ")
plt.bar(r_values,dist)
plt.show()

# %%
#Bernoulli Distribution
import matplotlib.pyplot as plt
from scipy.stats import bernoulli

#Instance of bernoulli distribution with parameter p = 0.6
bd = bernoulli(0.6)

#Outcome of a random variable can be 0,1
X = [0,1]

#Create a bar plot
plt.figure(figsize=(6,4))
plt.title("Bernoulli Distribution")
plt.xlim(-1,2)
plt.bar(X,bd.pmf(X),color='red')
plt.xlabel("Values of Random Variable X")
plt.ylabel("Probability ")
plt.show()

# %%
#Poisson Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
#Lam: Known number of occurrences 
#Size: The shape of the returned array
sns.displot(random.poisson(lam=5,size=100),kde=False)
plt.title("Poisson's Distribution")
plt.show()

# %%
#Normal Distribution
import numpy as np
import matplotlib.pyplot as plt

#creating a series of data in range of 1-50
X = np.linspace(1,50,100)

#Creating a function
def normal_dist(x,meann,sd):
    prob_density = (np.pi*sd) *np.exp(-0.5*((x-meann)/sd)**2)
    return prob_density

#Calculating Mean & Standard Deviation
mean=np.mean(X)
sd=np.std(X)

#Apply function to the data 
pdf= normal_dist(X,mean,sd)

#Plotting the data
plt.figure(figsize=(6,4))
plt.title("Normal Distribution")
plt.plot(X,pdf,color='red')
plt.xlabel("Values of Random Variable X")
plt.ylabel("Probability ")
plt.show()

# %%
#Continous Uniform Distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
plt.title("Uniform Distribution")
sns.distplot(random.uniform(size=1000),hist=True)
plt.show()
# Out:
# /var/folders/pt/19ssfcm95454p139wbpvht400000gn/T/ipykernel_54762/2170808419.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=1000),hist=True)

# %%
#Log Normal Distribution
import matplotlib.pyplot as plt
import numpy as np

meann,sdd = 2.,1. #mean and standard deviation
s=np.random.lognormal(meann,sdd,1000)
count,bins,ignored = plt.hist(s,50,density=True,align='mid')
x=np.linspace(min(bins),max(bins),10000)
pdf = (np.exp(-(np.log(x)-meann)**2/(2*sdd**2))/(x*sdd*np.sqrt(2*np.pi)))
plt.title("Log Normal Distribution")
plt.plot(x,pdf,linewidth=2,color='g')
plt.axis('tight')
plt.show()

# %%
#Exponential Distribution
import numpy as np
import matplotlib.pyplot as plt
 
#using Exponential()
pdf = np.random.exponential(3,1000)

plt.title("Exponential Distribution")
count,bins,ignored = plt.hist(pdf,10,density=True)
plt.show()

# %% [markdown]
# ## Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %%
import math

def normal_pdf(x, mean, std_dev):
    variance = std_dev ** 2
    exponent = -((x - mean) ** 2) / (2 * variance)
    coefficient = 1 / math.sqrt(2 * math.pi * variance)
    pdf = coefficient * math.exp(exponent)
    return pdf

#probability density function for x=5 ,mean = 2 and standard devaiation = 1
normal_pdf(5,2,1)
# Out:
# 0.0044318484119380075

# %% [markdown]
# ## Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials. A Bernoulli trial is an experiment with two possible outcomes: success (usually represented by "1") and failure (usually represented by "0").
#
# The binomial distribution has the following properties:
#
# 1. Fixed Number of Trials (n): The binomial distribution requires a fixed number of independent trials, denoted by "n." Each trial is assumed to be independent of the others, meaning the outcome of one trial does not affect the outcome of the others.
#
# 2. Two Outcomes: Each trial can result in one of two possible outcomes: success or failure. The probability of success on any given trial is denoted by "p," and the probability of failure is denoted by "q," where q = 1 - p.
#
# 3. Independent and Identically Distributed: The outcomes of each trial are independent and have the same probability of success (p) and failure (q).
#
# 4. Discrete: The binomial distribution deals with discrete random variables, meaning that the number of successes must be a whole number.
#
#
# Probability Mass Function (PMF): The probability mass function of the binomial distribution is given by the formula:
#
# P(X = k) = C(n, k) * p^k * q^(n-k)
#
# where:
#
# P(X = k) is the probability of getting exactly "k" successes in "n" trials.
# C(n, k) represents the number of ways to choose "k" successes out of "n" trials, also known as the binomial coefficient (n choose k).
#
# Examples of events where the binomial distribution can be applied:
#
# 1. Coin Flips: Consider a fair coin being flipped 10 times. Each flip has two possible outcomes: getting a head (success) with a probability of 0.5 and getting a tail (failure) with the same probability. The number of heads obtained in these 10 flips can be modeled using a binomial distribution.
#
# 2. Quality Control: A manufacturer tests a batch of 100 light bulbs, where each bulb has a probability of 0.95 of passing quality control (success) and a probability of 0.05 of failing (failure). The number of bulbs that pass quality control out of the 100 bulbs can be modeled using a binomial distribution.

# %% [markdown]
# ## Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a random sample of size 1000 from a Binomial distribution
n = 1000  # Sample size
p = 0.4  # Probability of success
sample = np.random.binomial(n, p, size=1000)

# Plot a histogram of the results using Fredman diaconis rule i.e. bins='fd'
plt.figure(figsize=(6,3))
plt.hist(sample,bins='fd',density=True, edgecolor='black')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution (n=1000, p=0.4)')
plt.show()

# %% [markdown]
# ## Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

# %% [markdown]
# ![Screenshot%202023-07-27%20at%206.13.50%20PM.png](attachment:Screenshot%202023-07-27%20at%206.13.50%20PM.png)

# %%
import math

def poisson_cdf(mean, point):
    cdf = 0
    for k in range(point + 1):
        cdf = cdf + math.exp(-mean) * pow(mean, k) / math.factorial(k)
    return cdf


#Calculating cdf for mean =6 ,x=2
result = poisson_cdf(mean=6,point=2)
print(f'Poison cdf for mean = 6 at x = 2 is {result}')


#Verifying the above value by importing poission from scipy.stats
from scipy.stats import poisson
print(f'Poison cdf using scipy.stats library for mean = 6 at x = 2 is {poisson.cdf(2,mu=6)}')
# Out:
# Poison cdf for mean = 6 at x = 2 is 0.06196880441665896
# Poison cdf using scipy.stats library for mean = 6 at x = 2 is 0.06196880441665898

# %% [markdown]
# ## Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# Binomial distribution and Poisson distribution are both probability distributions used to model the number of successes or occurrences of events. However, they are used in different scenarios and have distinct characteristics.
#
# Here are the key differences between the Binomial distribution and Poisson distribution:
#
# Number of Trials:
#
# Binomial Distribution: The binomial distribution is used when there are a fixed number of independent trials, each with the same probability of success.
# Poisson Distribution: The Poisson distribution is used when the number of trials is not fixed and can be considered as a limiting case of the binomial distribution when the number of trials becomes very large and the probability of success becomes very small.
# Nature of Events:
#
# Binomial Distribution: The binomial distribution is used for discrete events that have two possible outcomes, often referred to as success and failure.
# Poisson Distribution: The Poisson distribution is used for counting the number of events that occur in a fixed interval of time or space, where events occur randomly and independently of each other.
# Parameters:

# %% [markdown]
# ## Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# %%
import numpy as np

# Set the random seed for reproducibility
np.random.seed(4)

#Lam: Known number of occurrences 
#Size: The shape of the returned array
samp = np.random.poisson(lam=5,size=1000)

sample_mean = np.mean(samp)
sample_variance = np.var(samp)

print("Poission Sample Mean :", sample_mean)
print("Poission Sample Variance :", sample_variance)
# Out:
# Poission Sample Mean : 4.951
# Poission Sample Variance : 4.956599

# %% [markdown]
# ## Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# ### Binomial Distribution:
# In a binomial distribution, which models the number of successes in a fixed number of independent Bernoulli trials, the mean and variance are related as follows:
#
# - Mean (μ) = n * p
# - Variance (σ^2) = n * p * q
#
# Where:
#
# - n is the number of trials (sample size).
# - p is the probability of success in each trial.
# - q = 1 - p is the probability of failure in each trial.
#
# The mean of a binomial distribution is the product of the number of trials and the probability of success. The variance is the product of the number of trials, the probability of success, and the probability of failure. As the number of trials increases (larger 'n'), the variance tends to increase as well, making the spread of the distribution broader.
#
# ### Poisson Distribution:
#
# In a Poisson distribution, which models the number of events occurring in a fixed interval of time or space under certain conditions, the mean and variance are also related:
#
# - Mean (μ) = λ
# - Variance (σ^2) = λ
#
# Where:
# - λ (lambda) is the average rate of events occurring in the fixed interval.
#
# In the Poisson distribution, the mean and variance are both equal to the rate parameter λ. This means that the spread of the distribution is equal to the mean. Unlike the binomial distribution, the variance in the Poisson distribution does not change with the size of the sample or the number of events; it is solely determined by the rate parameter.

# %% [markdown]
# ## Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# In a normal distribution, also known as a Gaussian distribution, the least frequent data appears at the tails of the distribution, farthest away from the mean.
#
# The normal distribution is a symmetric probability distribution, meaning that it is evenly distributed around the mean and the following condition is true.
#
# Mean = Median = Mode
#
# The highest frequency of data points occurs around the mean, and as we move away from the mean in either direction, the frequency of data points gradually decreases. At the tails of the normal distribution, the data becomes increasingly rare, and the frequency of data points drops significantly. These tails extend indefinitely in both directions.
#
# For example, if we have a normal distribution with mean 0 and standard deviation 1, the least frequent data will appear in the tails of the distribution, which are the regions beyond 3 standard deviations from the mean. This is because the normal distribution is symmetric around the mean, and the probability density decreases rapidly as we move away from the mean towards the tails of the distribution. The probability of observing a value in the tails of a normal distribution is relatively low compared to the probability of observing a value closer to the mean.
#
#
# ![Standard_deviation_diagram.svg.png](attachment:Standard_deviation_diagram.svg.png)
